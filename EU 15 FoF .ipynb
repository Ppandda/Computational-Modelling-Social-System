# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset_2016 = {'source': ["BEL", "GER", "ITA", "NED", "ESP", "SWE", "GBR", 
                      "BEL", "FRA", "ITA", "NED", "ESP", "SWE", "GBR", 
                      "BEL", "FRA", "GER", "NED", "ESP", "SWE", "GBR", 
                      "BEL", "FRA", "GER", "ITA", "ESP", "SWE", "GBR", 
                      "BEL", "FRA", "GER", "ITA", "ESP", "SWE", "GBR", 
                      "BEL", "FRA", "GER", "ITA", "NED", "ESP", "GBR", 
                      "BEL", "FRA", "GER", "ITA", "NED", "ESP", "SWE", 
                      "FRA", "GER", "ITA", "NED", "ESP", "SWE", "GBR"],
           'target': ["FRA","FRA","FRA","FRA","FRA","FRA","FRA",
                      "GER","GER","GER","GER","GER","GER","GER",
                      "ITA","ITA","ITA","ITA","ITA","ITA","ITA",
                      "NED","NED","NED","NED","NED","NED","NED",
                      "ESP","ESP","ESP","ESP","ESP","ESP","ESP",
                      "SWE","SWE","SWE","SWE","SWE","SWE","SWE",
                      "GBR","GBR","GBR","GBR","GBR","GBR","GBR",
                      "BEL","BEL","BEL","BEL","BEL","BEL","BEL"],
           'weight': [-0.018,-0.011,0.383,0.140,0.091,0.321,-0.065,
                      -0.189,-0.268,0.042,0.140,-0.08,0.497,-0.065,
                      -0.189,0.245,-0.011,0.011,0.432,-0.186,-0.065,
                      0.495,0.117,-0.011,0.127,-0.08,0.241,-0.065,
                      -0.189,0.458,-0.011,0.213,-0.031,-0.229,-0.065,
                      -0.189,0.202,-0.011,-0.219,0.140,0.005,-0.065,
                      -0.189,-0.011,-0.011,-0.129,-0.159,0.091,-0.229,
                      0.416,-0.011,0.298,0.439,-0.08,-0.272,-0.065]}
df_2016 = pd.DataFrame(dataset_2016)
df_2016
# Out:
#    source target  weight
# 0     BEL    FRA  -0.018
# 1     GER    FRA  -0.011
# 2     ITA    FRA   0.383
# 3     NED    FRA   0.140
# 4     ESP    FRA   0.091
# 5     SWE    FRA   0.321
# 6     GBR    FRA  -0.065
# 7     BEL    GER  -0.189
# 8     FRA    GER  -0.268
# 9     ITA    GER   0.042
# 10    NED    GER   0.140
# 11    ESP    GER  -0.080
# 12    SWE    GER   0.497
# 13    GBR    GER  -0.065
# 14    BEL    ITA  -0.189
# 15    FRA    ITA   0.245
# 16    GER    ITA  -0.011
# 17    NED    ITA   0.011
# 18    ESP    ITA   0.432
# 19    SWE    ITA  -0.186
# 20    GBR    ITA  -0.065
# 21    BEL    NED   0.495
# 22    FRA    NED   0.117
# 23    GER    NED  -0.011
# 24    ITA    NED   0.127
# 25    ESP    NED  -0.080
# 26    SWE    NED   0.241
# 27    GBR    NED  -0.065
# 28    BEL    ESP  -0.189
# 29    FRA    ESP   0.458
# 30    GER    ESP  -0.011
# 31    ITA    ESP   0.213
# 32    ESP    ESP  -0.031
# 33    SWE    ESP  -0.229
# 34    GBR    ESP  -0.065
# 35    BEL    SWE  -0.189
# ...

# %%
dataset_2017 = {"source":["AUT", "DEN","FRA","GER","ITA","NED","POR","ESP","SWE","GBR","AUT","BEL","FRA","GER","ITA",
                            "NED","POR","ESP","SWE","GBR","AUT","BEL","DEN","GER","ITA","NED","POR","ESP","SWE","GBR","AUT","BEL",
                            "DEN","FRA","ITA","NED","POR","ESP","SWE","GBR","AUT","BEL","DEN","FRA","GER","NED","POR","ESP","SWE",
                            "GBR","AUT","BEL","DEN","FRA","GER","ITA","POR","ESP","SWE","GBR","AUT","BEL","DEN","FRA","GER","ITA",
                            "NED","ESP","SWE","GBR","AUT","BEL","DEN","FRA","GER","ITA","NED","POR","SWE","GBR","AUT","BEL","DEN",
                            "FRA","GER","ITA","NED","POR","ESP","GBR","AUT","BEL","DEN","FRA","GER","ITA","NED","POR","ESP","SWE",
                            "BEL","DEN","FRA","GER","ITA","NED","POR","ESP","SWE","GBR"], 
                "target": ["BEL","BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	
                            "DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",
                            "FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",
                            "GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",
                            "ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	
                            "NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",
                            "POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",
                            "ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",
                            "SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",
                            "GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",
                            "AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT"],
                "weight":[0.031,-0.08,	0.03,	-0.006,	-0.134,	0.271,	0.065,	-0.005,	0.240,
                            -0.03,	0.202,	-0.036,	-0.141,	-0.006,	-0.348,	0.1,	-0.149,	-0.005,	0.667,
                            -0.116,	-0.054,	-0.036,	-0.08,	-0.006,	0.293,	0.015,	0.235,	-0.005,	-0.017,
                            0.013,	-0.011,	0.049,	-0.08,	-0.141,	-0.177,	0.185,	0.150,	-0.005,	-0.188,
                            0.141,	-0.054,	0.006,	-0.08,	0.158,	-0.006,	-0.156,	-0.363,	-0.005,	0.069,
                            -0.116,	0.031,	0.134,	0.261,	-0.141,	-0.006,	-0.263,	0.235,	-0.005,	0.069,
                            0.098,	0.330,	0.391,	-0.08,	0.286,	-0.006,	-0.177,	-0.028,	0.208,	-0.017,
                            -0.116,	0.031,	-0.036,	-0.08,	-0.013,	-0.006,	0.421,	-0.028,	0.235,	0.069,
                            -0.073,	0.074,	0.117,	0.133,	-0.141,	-0.006,	-0.049,	-0.028,	0.150,	-0.005,
                            -0.116,	0.031,	-0.036,	0.005,	-0.141,	-0.006,	-0.263,	0.015,	0.065,	-0.005,
                            0.154,	0.049,	-0.08,	-0.141,	-0.006,	0.165,	0.356,	0.065,	-0.005,	-0.145,	-0.073]}

df_2017 = pd.DataFrame(dataset_2017)
df_2017
# Out:
#     source target  weight
# 0      AUT    BEL   0.031
# 1      DEN    BEL  -0.080
# 2      FRA    BEL   0.030
# 3      GER    BEL  -0.006
# 4      ITA    BEL  -0.134
# ..     ...    ...     ...
# 105    NED    AUT   0.356
# 106    POR    AUT   0.065
# 107    ESP    AUT  -0.005
# 108    SWE    AUT  -0.145
# 109    GBR    AUT  -0.073
#
# [110 rows x 3 columns]

# %%
dataset_2018 = {"source":["AUT","FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"GER",	"ITA",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"ITA",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"POR",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	
                            "ESP",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	
                            "POR",	"SWE",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	
                            "POR",	"ESP",	"GBR",	"AUT",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	
                            "POR",	"ESP",	"SWE",	"DEN",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	
                            "ESP",	"SWE",	"GBR"],
                "target":["DEN","DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	"DEN",	
                            "DEN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	
                            "FIN",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	
                            "FRA",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	
                            "GER",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	
                            "ITA",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	
                            "NED",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	
                            "POR",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	
                            "ESP",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	
                            "SWE",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	
                            "GBR",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	"AUT",	
                            "AUT"], 
                "weight":[0.420731707317073,0.0904471544715447,-0.186991869918699,0.191056910569106,0.0497967479674797,0.0904471544715447,0.194105691056911,0.0792682926829268,-0.0904471544715447,-0.0396341463414634,
                            0.0792682926829268,-0.0721544715447155,-0.186991869918699,0.0630081300813008,0.263211382113821,-0.0376016260162602,-0.0619918699186992,-0.0487804878048781,0.208333333333333,-0.0396341463414634,
                            -0.048780487804878,-0.114837398373984,0.133130081300813,-0.0650406504065041,0.0497967479674797,0.133130081300813,0.151422764227642,0.0792682926829268,-0.175813008130081,0.301829268292683,0.292682926829268,
                            0.0558943089430894,0.0904471544715447,-0.186991869918699,-0.163617886178862,0.0904471544715447,0.194105691056911,-0.00609756097560976,-0.175813008130081,-0.0396341463414634,-0.048780487804878,-0.285569105691057,-0.122967479674797,
                            0.32520325203252,-0.235772357723577,-0.122967479674797,-0.0619918699186992,0.207317073170732,-0.175813008130081,-0.0396341463414634,0.207317073170732,-0.0294715447154472,-0.122967479674797,-0.186991869918699,0.0630081300813008,
                            -0.0782520325203252,-0.0619918699186992,-0.0487804878048781,-0.175813008130081,0.0457317073170732,-0.00609756097560976,-0.285569105691057,-0.122967479674797,0.239837398373984,-0.278455284552846,0.561991869918699,-0.122967479674797,
                            -0.0487804878048781,0.0376016260162602,-0.0396341463414634,-0.00609756097560976,0.311991869918699,-0.122967479674797,-0.186991869918699,-0.193089430894309,-0.120934959349594,-0.122967479674797,-0.0619918699186992,0.251016260162602,
                            -0.0396341463414634,0.164634146341463,-0.157520325203252,-0.0802845528455285,-0.186991869918699,-0.278455284552846,-0.248983739837398,-0.0802845528455285,-0.0619918699186992,-0.0487804878048781,-0.0396341463414634,0.164634146341463,
                            -0.0721544715447155,-0.122967479674797,0.111788617886179,-0.193089430894309,0.00711382113821138,-0.122967479674797,-0.0193089430894309,-0.0487804878048781,-0.175813008130081,0.354674796747967,-0.0802845528455285,0.197154471544715,
                            0.0630081300813008,-0.163617886178862,-0.0802845528455285,-0.0619918699186992,-0.0487804878048781,-0.175813008130081,-0.0396341463414634]}

df_2018 = pd.DataFrame(dataset_2018)
df_2018
# Out:
#     source target    weight
# 0      AUT    DEN  0.420732
# 1      FIN    DEN  0.090447
# 2      FRA    DEN -0.186992
# 3      GER    DEN  0.191057
# 4      ITA    DEN  0.049797
# ..     ...    ...       ...
# 105    NED    AUT -0.080285
# 106    POR    AUT -0.061992
# 107    ESP    AUT -0.048780
# 108    SWE    AUT -0.175813
# 109    GBR    AUT -0.039634
#
# [110 rows x 3 columns]

# %%
dataset_2019 = {"source": ["DEN","GER",	"ITA",	"NED",	"ESP",	"SWE",	"GBR",	"DEN",	"FRA",	"ITA",	"NED",	"ESP",	"SWE",	"GBR",	"DEN",	
                            "FRA",	"GER",	"NED",	"ESP",	"SWE",	"GBR",	"DEN",	"FRA",	"GER",	"ITA",	"ESP",	"SWE",	"GBR",	"DEN",	"FRA",	"GER",	"ITA",	"NED",	
                            "SWE",	"GBR",	"DEN",	"FRA",	"GER",	"ITA",	"NED",	"ESP",	"GBR",	"DEN",	"FRA",	"GER",	"ITA",	"NED",	"ESP",	"SWE",	"FRA",	"GER",	
                            "ITA",	"NED",	"ESP",	"SWE",	"GBR"], 
                "target": ["FRA","FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"ITA",	"ITA",	"ITA",	
                            "ITA",	"ITA",	"ITA",	"ITA",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	
                            "SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"DEN",	"DEN",	"DEN",	"DEN",	
                            "DEN",	"DEN",	"DEN"], 
                "weight": [0.123931623931624,-0.0790598290598291,-0.217948717948718,0.0705128205128205,0.241452991452991,0.123931623931624,-0.0117521367521368,0.337606837606838,-0.116452991452991,
                            0.294871794871795,-0.228632478632479,-0.0576923076923077,0.337606837606838,-0.0117521367521368,0.209401709401709,-0.116452991452991,-0.0790598290598291,-0.271367521367521,-0.0576923076923077,
                            0.209401709401709,-0.0117521367521368,-0.132478632478632,-0.0737179487179487,-0.0790598290598291,0.294871794871795,0.0705128205128205,-0.132478632478632,-0.0117521367521368,0.337606837606838,
                            0.0972222222222222,-0.0790598290598291,0.166666666666667,0.412393162393162,0.337606837606838,-0.0117521367521368,0.166666666666667,0.182692307692308,-0.0790598290598291,0.0811965811965812,-0.356837606837607,
                            -0.0576923076923077,-0.0117521367521368,0.465811965811966,-0.0737179487179487,-0.0790598290598291,0.123931623931624,0.284188034188034,0.0277777777777778,0.465811965811966,-0.116452991452991,-0.0790598290598291,
                            0.123931623931624,0.583333333333333,-0.014957264957265,-0.217948717948718,-0.0117521367521368]}
df_2019 = pd.DataFrame(dataset_2019)
df_2019
# Out:
#    source target    weight
# 0     DEN    FRA  0.123932
# 1     GER    FRA -0.079060
# 2     ITA    FRA -0.217949
# 3     NED    FRA  0.070513
# 4     ESP    FRA  0.241453
# 5     SWE    FRA  0.123932
# 6     GBR    FRA -0.011752
# 7     DEN    GER  0.337607
# 8     FRA    GER -0.116453
# 9     ITA    GER  0.294872
# 10    NED    GER -0.228632
# 11    ESP    GER -0.057692
# 12    SWE    GER  0.337607
# 13    GBR    GER -0.011752
# 14    DEN    ITA  0.209402
# 15    FRA    ITA -0.116453
# 16    GER    ITA -0.079060
# 17    NED    ITA -0.271368
# 18    ESP    ITA -0.057692
# 19    SWE    ITA  0.209402
# 20    GBR    ITA -0.011752
# 21    DEN    NED -0.132479
# 22    FRA    NED -0.073718
# 23    GER    NED -0.079060
# 24    ITA    NED  0.294872
# 25    ESP    NED  0.070513
# 26    SWE    NED -0.132479
# 27    GBR    NED -0.011752
# 28    DEN    ESP  0.337607
# 29    FRA    ESP  0.097222
# 30    GER    ESP -0.079060
# 31    ITA    ESP  0.166667
# 32    NED    ESP  0.412393
# ...

# %%
dataset_2021 = {"source": ["BEL","FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	
                            "FIN",	"FRA",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	
                            "POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"SWE",	"GBR",	
                            "BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"FIN",	"FRA",	"GER",	"ITA",	
                            "NED",	"POR",	"ESP",	"SWE",	"GBR"], 
                "target": ["FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"GER",	"GER",	
                            "GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	
                            "NED",	"NED",	"NED",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"POR",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"SWE",	
                            "SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	
                            "BEL",	"BEL",	"BEL",	"BEL"], 
                "weight":[0.219594594594595,0.326576576576577,-0.0731981981981982,0.0180180180180181,-0.0563063063063063,-0.114864864864865,-0.00675675675675676,0.0867117117117117,0,0.00563063063063063,0.103603603603604,
                            -0.0731981981981982,0.103603603603604,0.114864864864865,0.0135135135135135,-0.00675675675675676,-0.0844594594594595,0,0.0484234234234234,-0.0247747747747748,0.027027027027027,-0.0247747747747748,-0.0563063063063063,
                            0.0135135135135135,-0.00675675675675676,-0.0416666666666667,0,-0.122747747747748,0.146396396396396,-0.486486486486487,-0.0731981981981982,0.0720720720720721,0.0563063063063063,-0.00675675675675676,0.00112612612612611,
                            0,-0.122747747747748,-0.0675675675675676,0.027027027027027,0.0123873873873874,-0.0675675675675676,-0.114864864864865,-0.00675675675675676,-0.0844594594594595,0,0.0484234234234234,0.103603603603604,0.0698198198198198,
                            -0.0731981981981982,0.103603603603604,-0.0563063063063063,-0.00675675675675676,-0.0844594594594595,0,-0.122747747747748,-0.153153153153153,0.240990990990991,-0.0731981981981982,-0.153153153153153,-0.0563063063063063,
                            -0.114864864864865,-0.0844594594594595,0,-0.122747747747748,0.103603603603604,-0.0585585585585585,-0.0731981981981982,0.103603603603604,-0.0563063063063063,-0.0720720720720721,-0.00675675675675676,0,-0.122747747747748,-0.238738738738739,
                            0.101351351351351,-0.0731981981981982,-0.238738738738739,0.0720720720720721,-0.114864864864865,0.0788288288288288,0.00112612612612611,0.445945945945946,0.198198198198198,-0.0731981981981982,0.445945945945946,-0.0563063063063063,-0.114864864864865,
                            -0.00675675675675676,-0.0416666666666667,0]}
df_2021 = pd.DataFrame(dataset_2021)
df_2021
# Out:
#    source target    weight
# 0     BEL    FIN  0.219595
# 1     FRA    FIN  0.326577
# 2     GER    FIN -0.073198
# 3     ITA    FIN  0.018018
# 4     NED    FIN -0.056306
# ..    ...    ...       ...
# 85    NED    BEL -0.056306
# 86    POR    BEL -0.114865
# 87    ESP    BEL -0.006757
# 88    SWE    BEL -0.041667
# 89    GBR    BEL  0.000000
#
# [90 rows x 3 columns]

# %%
dataset_2022 = {"source": ["BEL","FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"ITA",	
                            "NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"NED",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"POR",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	
                            "FRA",	"GER",	"ITA",	"NED",	"ESP",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"SWE",	"GBR",	"BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"GBR",	
                            "BEL",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"FIN",	"FRA",	"GER",	"ITA",	"NED",	"POR",	"ESP",	"SWE",	"GBR"], 
                "target": ["FIN","FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FIN",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"FRA",	"GER",	"GER",	"GER",	"GER",	"GER",	"GER",	
                            "GER",	"GER",	"GER",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"ITA",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"NED",	"POR",	"POR",	"POR",	"POR",	
                            "POR",	"POR",	"POR",	"POR",	"POR",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"ESP",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"SWE",	"GBR",	"GBR",	
                            "GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"GBR",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL",	"BEL"], 
                "weight": [0.273026315789474,-0.0712719298245614,-0.0701754385964912,-0.0635964912280702,0.0263157894736842,0.0263157894736842,-0.226973684210526,0.228070175438597,0.0263157894736842,-0.154605263157895,
                            -0.137061403508772,0.18640350877193,0.150219298245614,-0.0164473684210526,-0.0164473684210526,0.0723684210526316,-0.199561403508772,-0.0164473684210526,-0.154605263157895,0.0767543859649123,-0.0285087719298246,
                            0.150219298245614,0.154605263157895,0.154605263157895,-0.226973684210526,-0.0285087719298246,0.154605263157895,-0.154605263157895,-0.0515350877192983,0.270833333333333,0.229166666666667,0.411184210526316,
                            0.411184210526316,-0.184210526315789,-0.0285087719298246,0.411184210526316,-0.111842105263158,0.162280701754386,-0.0712719298245614,0.357456140350877,0.235745614035088,-0.1875,0.115131578947368,0.142543859649123,
                            -0.1875,-0.154605263157895,-0.137061403508772,-0.0712719298245614,-0.0701754385964912,0.0646929824561404,0.282894736842105,-0.226973684210526,-0.114035087719298,0.282894736842105,-0.154605263157895,0.205043859649123,
                            0.527412280701754,0.143640350877193,0.0219298245614035,-0.1875,-0.1875,-0.0712719298245614,-0.1875,0.273026315789474,0.290570175438597,-0.0712719298245614,-0.0274122807017544,-0.277412280701754,-0.144736842105263,
                            -0.144736842105263,-0.226973684210526,-0.144736842105263,0.144736842105263,0.119517543859649,0.0570175438596491,-0.0701754385964912,0.0646929824561404,-0.1875,-0.1875,-0.0986842105263158,0.0570175438596491,-0.0942982456140351,
                            -0.0712719298245614,-0.0701754385964912,0.0646929824561404,0.240131578947368,0.240131578947368,0.0296052631578947,-0.199561403508772,0.240131578947368]}
df_2022 = pd.DataFrame(dataset_2022)
df_2022
# Out:
#    source target    weight
# 0     BEL    FIN  0.273026
# 1     FRA    FIN -0.071272
# 2     GER    FIN -0.070175
# 3     ITA    FIN -0.063596
# 4     NED    FIN  0.026316
# ..    ...    ...       ...
# 85    NED    BEL  0.240132
# 86    POR    BEL  0.240132
# 87    ESP    BEL  0.029605
# 88    SWE    BEL -0.199561
# 89    GBR    BEL  0.240132
#
# [90 rows x 3 columns]

# %%
G = nx.from_pandas_edgelist(dataset_2016, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(G, seed=13)

#nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(G, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2016")
plt.savefig("2016.png")
plt.show()

# %%
H = nx.from_pandas_edgelist(dataset_2017, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in H.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in H.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(H, seed=13)

#nodes
nx.draw_networkx_nodes(H, pos, node_size=700)

# edges
nx.draw_networkx_edges(H, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(H, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(H, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2017")
plt.savefig("2017.png")
plt.show()

# %%
I = nx.from_pandas_edgelist(dataset_2018, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in I.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in I.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(I, seed=13)

#nodes
nx.draw_networkx_nodes(I, pos, node_size=700)

# edges
nx.draw_networkx_edges(I, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(I, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(I, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2018")
plt.savefig("2018.png")
plt.show()

# %%
J = nx.from_pandas_edgelist(dataset_2019, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in J.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in J.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(J, seed=13)

#nodes
nx.draw_networkx_nodes(J, pos, node_size=700)

# edges
nx.draw_networkx_edges(J, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(J, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(J, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2019")
plt.savefig("2019.png")
plt.show()

# %%
K = nx.from_pandas_edgelist(dataset_2021, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in K.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in K.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(K, seed=13)

#nodes
nx.draw_networkx_nodes(K, pos, node_size=700)

# edges
nx.draw_networkx_edges(K, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(K, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(K, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2021")
plt.savefig("2021.png")
plt.show()

# %%
L = nx.from_pandas_edgelist(dataset_2022, source= "source", target="target", edge_attr="weight")

#seperate weight for respective coloring
elarge = [(u, v) for (u, v, d) in L.edges(data=True) if d["weight"] > 0.00001]
esmall = [(u, v) for (u, v, d) in L.edges(data=True) if d["weight"] <= 0.00001]

#setting seed
pos=nx.random_layout(L, seed=13)

#nodes
nx.draw_networkx_nodes(L, pos, node_size=700)

# edges
nx.draw_networkx_edges(L, pos, edge_color="blue", edgelist=elarge, width=3, alpha=0.5)
nx.draw_networkx_edges(L, pos, edge_color="red", edgelist=esmall, width=3, alpha=0.5)

# node labels
nx.draw_networkx_labels(L, pos, font_size=20, font_family="sans-serif")

# edge weight labels
#edge_labels = nx.get_edge_attributes(G, "weight")
#nx.draw_networkx_edge_labels(G, pos, edge_labels)

#plotting
ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
#plt.tight_layout()
plt.title("2022")
plt.savefig("2022.png")
plt.show()
